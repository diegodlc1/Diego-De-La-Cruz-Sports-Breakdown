# %% [markdown]
# # New York Knicks Offseason #

# %% [markdown]
# After falling in Game 7 to the Pacers, the Knicks are out of the playoffs once again. With the Knicks losing in the second round in the East the past 2 years, we should expect to see some moves being made by this team, however the question is what?

# %% [markdown]
# ## Current Situation ##

# %% [markdown]
# This is the Knicks current contract situation according to basketball refernce.

# %%
import pandas as pd

data = [
    ["Julius Randle", 29, "$28,226,880", "$30,317,760", "$32,408,640", None, None, None, "$58,544,640"],
    ["Jalen Brunson", 27, "$26,346,666", "$24,960,001", "$24,960,001", None, None, None, "$51,306,667"],
    ["Bojan Bogdanović", 35, "$20,000,000", "$19,032,850", None, None, None, None, "$20,000,000"],
    ["OG Anunoby", 26, "$18,642,857", "$19,928,571", None, None, None, None, "$18,642,857"],
    ["Mitchell Robinson", 26, "$15,681,818", "$14,318,182", "$12,954,546", None, None, None, "$42,954,546"],
    ["Josh Hart", 29, "$12,960,000", "$18,144,000", "$19,472,240", "$20,923,760", "$22,375,280", None, "$71,500,000"],
    ["Donte DiVincenzo", 27, "$10,900,000", "$11,445,000", "$11,990,000", "$12,535,000", None, None, "$46,870,000"],
    ["Alec Burks", 32, "$10,489,600", None, None, None, None, None, "$10,489,600"],
    ["Isaiah Hartenstein", 26, "$9,245,121", None, None, None, None, None, "$9,245,121"],
    ["Precious Achiuwa", 24, "$4,379,527", None, None, None, None, None, "$4,379,527"],
    ["Jericho Sims", 25, "$1,927,896", "$2,092,344", None, None, None, None, "$600,000"],
    ["Miles McBride", 23, "$1,836,096", "$4,710,144", "$4,333,333", "$3,956,523", None, None, "$14,836,096"],
    ["DaQuan Jeffries", 26, "$831,385", None, None, None, None, None, "$831,385"],
    ["Mamadi Diakite", 27, None, None, None, None, None, None, None],
    ["Shake Milton", 27, None, None, None, None, None, None, None],
    ["Charlie Brown Jr.", 27, None, None, None, None, None, None, None],
    ["Jacob Toppin", 24, None, None, None, None, None, None, None],
    ["Duane Washington Jr.", 24, None, None, None, None, None, None, None],
    ["Dylan Windler", 27, "$2,019,706", None, None, None, None, None, "$2,019,706"],
    ["Taj Gibson", 38, "$477,630", None, None, None, None, None, "$845,038"],
    ["Team Totals", None, "$163,965,182", "$144,948,852", "$106,118,760", "$37,415,283", "$22,375,280", None, "$353,065,183"]
]

df = pd.DataFrame(data, columns=["Player", "Age", "2023-24", "2024-25", "2025-26", "2026-27", "2027-28", "2028-29", "Guaranteed"])
df
# Out:
#                   Player   Age       2023-24       2024-25       2025-26  \
# 0          Julius Randle  29.0   $28,226,880   $30,317,760   $32,408,640
# 1          Jalen Brunson  27.0   $26,346,666   $24,960,001   $24,960,001
# 2       Bojan Bogdanović  35.0   $20,000,000   $19,032,850          None
# 3             OG Anunoby  26.0   $18,642,857   $19,928,571          None
# 4      Mitchell Robinson  26.0   $15,681,818   $14,318,182   $12,954,546
# 5              Josh Hart  29.0   $12,960,000   $18,144,000   $19,472,240
# 6       Donte DiVincenzo  27.0   $10,900,000   $11,445,000   $11,990,000
# 7             Alec Burks  32.0   $10,489,600          None          None
# 8     Isaiah Hartenstein  26.0    $9,245,121          None          None
# 9       Precious Achiuwa  24.0    $4,379,527          None          None
# 10          Jericho Sims  25.0    $1,927,896    $2,092,344          None
# 11         Miles McBride  23.0    $1,836,096    $4,710,144    $4,333,333
# ...

# %% [markdown]
# Currently, the Knicks have 7 roster spots guaranteed with Anunoby having a player option and Sims on a team option. They also have 2 late firsts and an early second-round draft pick this year. The 2 firsts will account for an extra 4.6 million dollars, and the early second I would say accounts for 1.1 million dollars. With this, these 3 players will add to the 7 already on the roster for a total salary being around 150.6 million dollars. I will go into what the Knicks need to do with the contracts on the roster for this year, and the next year, and look into potential trade and free agents.

# %% [markdown]
# ## Current Contracts ##

# %% [markdown]
# First, let's talk about the options. OG will not pick up his player option. He is going to be worth more than the 19.9 million he has on the option. I'm not saying that he won't resign with the Knicks, however, I don't see that happening with his current deal. With that being said, the Knicks shouldn't pick up his option. With all of that the Knicks will be around 128.6 million dollars.
#
# With this, there are now 4 players that would need to be handled with. Anunoby, Burks, Hartenstein, and Achiuwa.
#
# Burks: First let's start with the easiest one. Burks is not good anymore. They could try and resign him for a min, but he's not worth more than that. He should be set to leave.
#
# Anunoby: Another easier one, the Knicks need to try and resign him. He is worth the price, even if it's putting them over the salary cap. I see a 4-year, 120-million-dollar contract having the Knicks cap at 158.6 million.
#
# Hartenstein and Achiuwa: This is a situation of one or the other. Hartenstein has early bird rights and could receive the qualifying offer, but Hartenstein will get more than enough to put the Knicks over the first apron. Achiuwa can get a qualifying offer for 13.1 million, which would be more than what he is truly worth, but they would still be under the first apron that they can get a player for the TPMLE. The question is either just Hartenstein or Achiuwa and a TPMLE.

# %% [markdown]
# ## Next Year Contracts ##

# %% [markdown]
# The only question for next years contracts is to resign Bogdanović or not. The simple answer is at least not for what his salary is at the moment. He could be of some use during the year on the vet min. Anything more than that isn't worth his contract. Other than this move the Knicks only have player options for next year and any one year deals that free agents from this year can get.

# %% [markdown]
# ## Free Agents and Trades ##

# %% [markdown]
# At the most, all I can see is a player that is signed for the TPMLE or vet mins. Achiuwa or Hartenstein will be the main decision this offseason. This would just be mins and maybe a TPMLE.
#
# While trades could happen with both Brunson and Randle having expiring deals, I don't see much change here at the moment. If I'm the Knicks I want to see what Randle can do with this team in the playoffs. Maybe Mitchell Robinson, but I think only a tanking team would take on his contract, maybe a team on the rise would take a chance on him. Bogi would be another shout but a tanking team would only take his contract with some draft capital added onto it.

# %% [markdown]
# ## What Would I do ##

# %% [markdown]
# Everything I mentioned above Hartenstein and Achiuwa I would do. The Knicks cap space would be at 158.6 million dollars. I would have around 20 million to play with before hitting the first apron. If I'm the Knicks I'm trying to keep Hartenstein. Hartenstein would be the choice if the Knicks can find a trade with Bogi. If the trade can't happen or Hartenstein is going for more than what the Knicks want to pay, then Achiuwa and the TPMLE would be the best option. For the Knicks to be better it is to go with the first option, keep Hartenstein, and find a trade for Bogi.
#
# These are 2 realistic trades that I would do:
#
# Knicks Receive: Davis Bertans
#
# Charlotte Recieve: Bojan Bogdanović
#
# The Knicks get a scoring Power Forward who can come off the bench and be a scorer. The Knicks also can save 3 million this year. The Hornets take this to have an extra 3 million in balance for next year's free agency.
#
# Another thought is this one:
#
# Knicks Receive: Dorian Finney Smith
#
# Brooklyn Recieve: Bojan Bogdanović, Unprotected First-Round Pick
#
# DFS is a better player than Bertans and fits more in coach Thibs' philosophy, however, the Knicks have to give up a first-round pick for the extra value, freeing up 5 million in cap space for the Knicks. The Nets get a first back while also freeing up DFS' player option the next year from the books to have more money for next year's free agency.
#
# If I were the Knicks I would do the Nets trade. Getting DFS is better to have off the bench than Bertans. The Knicks need to compete for the now and that is what will be a necessary move to make them have the final push.
#
# Based on this I see this being the best lineup would be.
#
# Starter, Bench
#
# PG: Brunson, McBride
#
# SG: DiVincenzo, Vet FA
#
# SF: Anunoby, Hart
#
# PF: Randle, DFS
#
# C: Hartenstein, Robinson
